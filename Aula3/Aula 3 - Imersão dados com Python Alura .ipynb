# %% [markdown]
# # AULA 1

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print("linhas:", linhas)
print("colunas:", colunas)
# Out:
# linhas: 133349
# colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.columns = [
    'ano',
    'senerioridade',
    'contrato',
    'cargo',
    'salario',
    'moeda',
    'usd',
    'residencia',
    'remoto',
    'empresa',
    'tamanho_empresa'
]

print("Colunas traduzidas com sucesso! Novas colunas:")
print(df.columns)
# Out:
# Colunas traduzidas com sucesso! Novas colunas:
# Index(['ano', 'senerioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['ano', 'senerioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["nivel_experiencia"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nivel_experiencia'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2933530220.py in <cell line: 0>()
# ----> 1 df["nivel_experiencia"].value_counts()
#
# ...

# %%
df["tipo_emprego"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tipo_emprego'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4151121601.py in <cell line: 0>()
# ----> 1 df["tipo_emprego"].value_counts()
#
# ...

# %%
df["cargo"].value_counts()
# Out:
# cargo
# Data Scientist                     17314
# Software Engineer                  15007
# Data Engineer                      14868
# Data Analyst                       12381
# Engineer                            9456
#                                    ...
# Quantitative Research Analyst          1
# Data Science Tech Lead                 1
# Staff Machine Learning Engineer        1
# Principal Data Architect               1
# Cloud Data Architect                   1
# Name: count, Length: 390, dtype: int64

# %%
df["taxa_remoto"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'taxa_remoto'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2091539449.py in <cell line: 0>()
# ----> 1 df["taxa_remoto"].value_counts()
#
# ...

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
df['senerioridade'] = df['senerioridade'].replace({
    'SE': 'Sênior',
    'MI': 'Médio',
    'EN': 'Júnior',
    'EX': 'Executivo'
})

print("Categorias de 'senerioridade' traduzidas com sucesso! Novas contagens:")
print(df['senerioridade'].value_counts())
# Out:
# Categorias de 'senerioridade' traduzidas com sucesso! Novas contagens:
# senerioridade
# Sênior       77241
# Médio        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
df['contrato'] = df['contrato'].replace({
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
})

print("Categorias de 'contrato' traduzidas com sucesso! Novas contagens:")
print(df['contrato'].value_counts())
# Out:
# Categorias de 'contrato' traduzidas com sucesso! Novas contagens:
# contrato
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
df['tamanho_empresa'] = df['tamanho_empresa'].replace({
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
})

print("Categorias de 'tamanho_empresa' traduzidas com sucesso! Novas contagens:")
print(df['tamanho_empresa'].value_counts())
# Out:
# Categorias de 'tamanho_empresa' traduzidas com sucesso! Novas contagens:
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
print("Primeiras linhas do DataFrame com as traduções confirmadas:")
df.head(10)
# Out:
# Primeiras linhas do DataFrame com as traduções confirmadas:
#       ano senerioridade        contrato               cargo  salario moeda  \
# 0  2025.0        Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0        Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0         Médio  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0         Médio  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0        Júnior  Tempo Integral       Data Engineer    90000   USD
# 5  2025.0        Júnior  Tempo Integral       Data Engineer    80000   USD
# 6  2025.0        Sênior  Tempo Integral      Data Scientist   185000   USD
# 7  2025.0        Sênior  Tempo Integral      Data Scientist   148000   USD
# 8  2025.0         Médio  Tempo Integral      Data Scientist   135000   USD
# 9  2025.0         Médio  Tempo Integral      Data Scientist   108000   USD
#
#       usd residencia  remoto empresa tamanho_empresa
# ...

# %%
""df""['cargo'] = ""df""['cargo'].replace({
    'Data Scientist': 'Cientista de Dados',
    'Software Engineer': 'Engenheiro de Software',
    'Data Engineer': 'Engenheiro de Dados',
    'Data Analyst': 'Analista de Dados',
    'Engineer': 'Engenheiro'
})

print("Categorias de 'cargo' traduzidas com sucesso! Novas contagens (top 10):")
print(""df""['cargo'].value_counts().head(10))
# Out:
#   File "/tmp/ipython-input-825197217.py", line 1
#     ""df""['cargo'] = ""df""['cargo'].replace({
#       ^
# SyntaxError: invalid syntax

# %%
print("Primeiras linhas do DataFrame com as traduções confirmadas:")
df.head()
# Out:
# Primeiras linhas do DataFrame com as traduções confirmadas:
#       ano senerioridade        contrato               cargo  salario moeda  \
# 0  2025.0        Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0        Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0         Médio  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0         Médio  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0        Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia  remoto empresa tamanho_empresa
# 0  214000         US     100      US           Médio
# 1  136000         US     100      US           Médio
# 2  158800         AU       0      AU           Médio
# 3  139200         AU       0      AU           Médio
# 4   90000         US       0      US           Médio

# %%
df['contrato'] = df['contrato'].replace({
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
})

print("Categorias de 'contrato' traduzidas com sucesso! Novas contagens:")
print(df['contrato'].value_counts())
# Out:
# Categorias de 'contrato' traduzidas com sucesso! Novas contagens:
# contrato
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
df.describe(include="object")
# Out:
#        senerioridade        contrato           cargo   moeda residencia  \
# count         133349          133349          133349  133349     133349
# unique             4               4             390      26        102
# top           Sênior  Tempo Integral  Data Scientist     USD         US
# freq           77241          132563           17314  126140     119579
#
#        empresa tamanho_empresa
# count   133349          133349
# unique      95               3
# top         US           Médio
# freq    119641          129561

# %%
df.head()
# Out:
#       ano senerioridade        contrato               cargo  salario moeda  \
# 0  2025.0        Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0        Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0         Médio  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0         Médio  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0        Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia  remoto empresa tamanho_empresa
# 0  214000         US     100      US           Médio
# 1  136000         US     100      US           Médio
# 2  158800         AU       0      AU           Médio
# 3  139200         AU       0      AU           Médio
# 4   90000         US       0      US           Médio

# %%
df.describe()
# Out:
#                  ano       salario            usd         remoto
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df['remoto'] = df['remoto'].replace({
    100: 'Remoto',
    0: 'Presencial',
    50: 'Híbrido'
})

print("Categorias de 'remoto' traduzidas com sucesso! Novas contagens:")
print(df['remoto'].value_counts())
# Out:
# Categorias de 'remoto' traduzidas com sucesso! Novas contagens:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %% [markdown]
# # AULA 2

# %%
df.isnull()
# Out:
#           ano  senerioridade  contrato  cargo  salario  moeda    usd  \
# 0       False          False     False  False    False  False  False
# 1       False          False     False  False    False  False  False
# 2       False          False     False  False    False  False  False
# 3       False          False     False  False    False  False  False
# 4       False          False     False  False    False  False  False
# ...       ...            ...       ...    ...      ...    ...    ...
# 133344  False          False     False  False    False  False  False
# 133345  False          False     False  False    False  False  False
# 133346  False          False     False  False    False  False  False
# 133347  False          False     False  False    False  False  False
# 133348  False          False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# ...

# %%
df.head(20)
# Out:
#        ano senerioridade        contrato               cargo  salario moeda  \
# 0   2025.0        Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1   2025.0        Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2   2025.0         Médio  Tempo Integral       Data Engineer   158800   USD
# 3   2025.0         Médio  Tempo Integral       Data Engineer   139200   USD
# 4   2025.0        Júnior  Tempo Integral       Data Engineer    90000   USD
# 5   2025.0        Júnior  Tempo Integral       Data Engineer    80000   USD
# 6   2025.0        Sênior  Tempo Integral      Data Scientist   185000   USD
# 7   2025.0        Sênior  Tempo Integral      Data Scientist   148000   USD
# 8   2025.0         Médio  Tempo Integral      Data Scientist   135000   USD
# 9   2025.0         Médio  Tempo Integral      Data Scientist   108000   USD
# 10  2025.0         Médio  Tempo Integral        BI Developer   118000   USD
# ...

# %%
df.isnull().sum()
# Out:
# ano                10
# senerioridade       0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senerioridade        contrato                      cargo  salario  \
# 5588    NaN        Sênior  Tempo Integral            Product Manager   184500
# 59692   NaN         Médio  Tempo Integral                   Engineer   110000
# 59710   NaN        Júnior  Tempo Integral             Data Scientist   208800
# 59759   NaN        Sênior  Tempo Integral          Software Engineer   135000
# 59789   NaN        Sênior  Tempo Integral                   Engineer   112000
# 131000  NaN        Sênior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN        Sênior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN        Júnior  Tempo Integral             Data Scientist    40000
# 133281  NaN         Médio  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN         Médio  Tempo Integral             Data Scientist   130000
#
#        moeda     usd residencia      remoto empresa tamanho_empresa
# ...

# %%
import numpy as np

df_salarios = pd.DataFrame({
    "nome":['Bruno','Emily',"Ana",'Erick', 'Valkiria', 'Robson'],
    "salario":[4000, np.nan, 5000, np.nan, 100000, 5700]
})

#calcula a média e substitui os nulos e arredonda
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

#Calcula a mediana e substitui os nulos
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#        nome   salario  salario_media  salario_mediana
# 0     Bruno    4000.0         4000.0           4000.0
# 1     Emily       NaN        28675.0           5350.0
# 2       Ana    5000.0         5000.0           5000.0
# 3     Erick       NaN        28675.0           5350.0
# 4  Valkiria  100000.0       100000.0         100000.0
# 5    Robson    5700.0         5700.0           5700.0

# %%
df_temperaturas = pd.DataFrame({
    "dia":['segunda','terça','quarta','quinta','sexta','sabado','domingo'],
    "temperatura":[30, np.nan, np.nan, 28, 27, 25, 26]
})
#pega a temperatura do dia anterior
df_temperaturas["preenchido_ffill"] = df_temperaturas["temperatura"].ffill()
df_temperaturas
# Out:
#        dia  temperatura  preenchido_ffill
# 0  segunda         30.0              30.0
# 1    terça          NaN              30.0
# 2   quarta          NaN              30.0
# 3   quinta         28.0              28.0
# 4    sexta         27.0              27.0
# 5   sabado         25.0              25.0
# 6  domingo         26.0              26.0

# %%
df_temperaturas = pd.DataFrame({
    "dia":['segunda','terça','quarta','quinta','sexta','sabado','domingo'],
    "temperatura":[30, np.nan, np.nan, 28, 27, 25, 26]
})
#pega a temperatura do dia seguinte
df_temperaturas["preenchido_bfill"] = df_temperaturas["temperatura"].bfill()
df_temperaturas
# Out:
#        dia  temperatura  preenchido_bfill
# 0  segunda         30.0              30.0
# 1    terça          NaN              28.0
# 2   quarta          NaN              28.0
# 3   quinta         28.0              28.0
# 4    sexta         27.0              27.0
# 5   sabado         25.0              25.0
# 6  domingo         26.0              26.0

# %%
df_cidades = pd.DataFrame({
    "nome":['Bruno','Emily',"Ana",'Erick', 'Valkiria', 'Robson'],
    "cidade":['Osasco', 'São Paulo', np.nan, 'Curitiba', np.nan, np.nan]
})

df_cidades["cidade_preenchida"] = df_cidades["cidade"].fillna("cidade não informada")
df_cidades
# Out:
#        nome     cidade     cidade_preenchida
# 0     Bruno     Osasco                Osasco
# 1     Emily  São Paulo             São Paulo
# 2       Ana        NaN  cidade não informada
# 3     Erick   Curitiba              Curitiba
# 4  Valkiria        NaN  cidade não informada
# 5    Robson        NaN  cidade não informada

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senerioridade      0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senerioridade        contrato               cargo  salario moeda  \
# 0  2025.0        Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0        Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0         Médio  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0         Médio  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0        Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senerioridade    133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
#muda o tipo de dado tratado na coluna ano
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))
df_limpo.head()
# Out:
#     ano senerioridade        contrato               cargo  salario moeda  \
# 0  2025        Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025        Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025         Médio  Tempo Integral       Data Engineer   158800   USD
# 3  2025         Médio  Tempo Integral       Data Engineer   139200   USD
# 4  2025        Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %% [markdown]
# #AULA 3

# %%
df_limpo.head()
# Out:
#     ano senerioridade        contrato               cargo  salario moeda  \
# 0  2025        Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025        Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025         Médio  Tempo Integral       Data Engineer   158800   USD
# 3  2025         Médio  Tempo Integral       Data Engineer   139200   USD
# 4  2025        Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_limpo['senerioridade'].value_counts().plot(kind='bar',title = "distribuição de senhoridade")
# Out:
# <Axes: title={'center': 'distribuição de senhoridade'}, xlabel='senerioridade'>

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
sns.barplot(data=df_limpo,x='senerioridade',y='usd')
# Out:
# <Axes: xlabel='senerioridade', ylabel='usd'>

# %%
plt.figure('figsize=8,5')
sns.barplot(data=df_limpo,x='senerioridade',y='usd')
plt.title("Salário médio por nível de senerioridade")
plt.xlabel("Senerioridade")
plt.ylabel("Salário médio anual (USD)")
plt.show()

# %%
df_limpo.groupby("senerioridade")["usd"].mean().sort_values(ascending=False)
# Out:
# senerioridade
# Executivo    202027.667813
# Sênior       172850.838301
# Médio        143044.845979
# Júnior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby("senerioridade")["usd"].mean().sort_values(ascending=True).index
print(ordem)
# Out:
# Index(['Júnior', 'Médio', 'Sênior', 'Executivo'], dtype='object', name='senerioridade')

# %%
plt.figure('figsize=8,5')
sns.barplot(data=df_limpo,x='senerioridade',y='usd',order = ordem)
plt.title("Salário médio por nível de senerioridade")
plt.xlabel("Senerioridade")
plt.ylabel("Salário médio anual (USD)")
plt.show()

# %%
plt.figure('figsize=8,5')
sns.histplot(df_limpo["usd"], bins = 50, kde=True)
plt.title("Distyribuição dos salários anuais")
plt.xlabel("salário em USD")
plt.ylabel("Frequência")
plt.show()

# %%
plt.figure('figsize=8,5')
sns.boxplot(x=df_limpo['usd'])
plt.title("BoxPlot Salário")
plt.xlabel("Salário em USD")
plt.show()

# %%
df_limpo['senerioridade'] = df_limpo['senerioridade'].replace({
    'SE': 'Sênior',
    'MI': 'Médio',
    'EN': 'Júnior',
    'EX': 'Executivo'
})

ordem_senerioridade = ['Júnior','Médio','Sênior','Executivo']
plt.figure('figsize=8,5')
sns.boxplot(x='senerioridade',y='usd',data=df_limpo, order=ordem_senerioridade)
plt.title("distribuição salarial por senerioridade")
plt.xlabel("Salário em USD")
plt.show()

# %%
ordem_senerioridade = ['Júnior','Médio','Sênior','Executivo']
plt.figure('figsize=8,5')
sns.boxplot(x='senerioridade',y='usd',data=df_limpo, order=ordem_senerioridade, palette='Set2', hue='senerioridade')
plt.title("distribuição salarial por senerioridade")
plt.xlabel("Salário em USD")
plt.show()

# %%
import plotly.express as px

# %%
df_media_senerioridade = df_limpo.groupby('senerioridade')['usd'].mean().reset_index()

fig = px.bar(
    df_media_senerioridade,
    x='senerioridade',
    y='usd',
    title='Média Salarial por Senioridade',
    labels={'senerioridade': 'Senioridade', 'usd': 'Média Salarial (USD)'},
    category_orders={'senerioridade': ['Júnior', 'Médio', 'Sênior', 'Executivo']},
    color='senerioridade'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho','quantidade']

fig = px.pie(
    remoto_contagem,
    names = 'tipo_trabalho',
    values = 'quantidade',
    title='proporção dos tipos de trabalho',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho','quantidade']

fig = px.pie(
    remoto_contagem,
    names = 'tipo_trabalho',
    values = 'quantidade',
    title='proporção dos tipos de trabalho',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho','quantidade']

fig = px.pie(
    remoto_contagem,
    names = 'tipo_trabalho',
    values = 'quantidade',
    title='proporção dos tipos de trabalho',
    hole=0.4
)
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print("Contagens atuais da coluna 'cargo' em df_limpo antes de qualquer alteração:")
print(df_limpo['cargo'].value_counts().head())
# Out:
# Contagens atuais da coluna 'cargo' em df_limpo antes de qualquer alteração:
# cargo
# Data Scientist       17311
# Software Engineer    15006
# Data Engineer        14868
# Data Analyst         12381
# Engineer              9454
# Name: count, dtype: int64

# %%
df_limpo['cargo'] = df_limpo['cargo'].replace({
    'Data Scientist': 'Cientista de Dados',
    'Software Engineer': 'Engenheiro de Software',
    'Data Engineer': 'Engenheiro de Dados',
    'Data Analyst': 'Analista de Dados',
    'Engineer': 'Engenheiro'
})

print("Categorias de 'cargo' traduzidas com sucesso! Novas contagens (top 10):")
print(df_limpo['cargo'].value_counts().head(10))
# Out:
# Categorias de 'cargo' traduzidas com sucesso! Novas contagens (top 10):
# cargo
# Cientista de Dados           17312
# Engenheiro de Software       15006
# Engenheiro de Dados          14868
# Analista de Dados            12381
# Engenheiro                    9454
# Machine Learning Engineer     8203
# Manager                       6679
# Analyst                       4364
# Research Scientist            3202
# Product Manager               2229
# Name: count, dtype: int64

# %% [markdown]
# #ATIVIDADE AULA 3

# %%
df_cargo = df_limpo[['cargo', 'usd', 'residencia']]
df_cargo.head(25)
# Out:
#                   cargo     usd residencia
# 0    Solutions Engineer  214000         US
# 1    Solutions Engineer  136000         US
# 2   Engenheiro de Dados  158800         AU
# 3   Engenheiro de Dados  139200         AU
# 4   Engenheiro de Dados   90000         US
# 5   Engenheiro de Dados   80000         US
# 6    Cientista de Dados  185000         US
# 7    Cientista de Dados  148000         US
# 8    Cientista de Dados  135000         CA
# 9    Cientista de Dados  108000         CA
# 10         BI Developer  118000         US
# 11         BI Developer   51000         US
# 12    Analista de Dados   91900         US
# 13    Analista de Dados   54300         US
# 14    Applied Scientist  255000         US
# 15    Applied Scientist  190000         US
# 16     Systems Engineer  196350         US
# 17     Systems Engineer  130900         US
# 18             Director  170000         US
# 19             Director  160000         US
# 20            Associate  119000         CA
# ...

# %%
df_cientistas_dados = df_cargo[df_cargo['cargo'] == 'Cientista de Dados'][['residencia', 'usd']].reset_index(drop=True)
df_cientistas_dados.head(10)
# Out:
#   residencia     usd
# 0         US  185000
# 1         US  148000
# 2         CA  135000
# 3         CA  108000
# 4         US  258000
# 5         US  119800
# 6         US  175074
# 7         US   79560
# 8         US  117000
# 9         US   90000

# %%
fig = px.box(
    df_cientistas_dados,
    x='residencia',
    y='usd',
    title='Média Salarial dos Cientistas de Dados por País',
    labels={'residencia': 'Pais de residencia', 'usd': 'Média Salarial Anual (USD)'},
    color='residencia'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
